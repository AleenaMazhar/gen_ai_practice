# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(model="gemini-3.7-flash")

# %%
with open("blood_work.txt", "r") as f:
    blood_report = f.read()

print(blood_report[:200])
# Out:
# Patient: Aleena Mazhar, Age 23, Female
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5â€“17.5)
# Hematocrit:        44%

# %%
prompt = f"""
You are a medical data extraction assistant. 

From the blood report below, extract all text values and classify each one as HIGH, LOW or NORMAL 
based on the reference ranges provided in the report.

Format your response as:
- Test Name: value | Status: HIGH/LOW/NORMAL | Reference: range

Blood report:
{blood_report}
"""

extraction_response = llm.invoke(prompt)
extracted_values = extraction_response.text

print("== Stage 1: Extracted Values ==")
print(extracted_values)
# Out:
# == Stage 1: Extracted Values ==
# - Hemoglobin: 15.1 g/dL | Status: NORMAL | Reference: 13.5–17.5
# - Hematocrit: 44% | Status: NORMAL | Reference: 41–53%
# - WBC: 6.8 x10^3/uL | Status: NORMAL | Reference: 4.5–11.0
# - Platelets: 220 x10^3/uL | Status: NORMAL | Reference: 150–400
# - Total Cholesterol: 238 mg/dL | Status: HIGH | Reference: <200
# - LDL Cholesterol: 162 mg/dL | Status: HIGH | Reference: <100
# - HDL Cholesterol: 36 mg/dL | Status: LOW | Reference: >40
# - Triglycerides: 188 mg/dL | Status: HIGH | Reference: <150
# - Glucose (Fasting): 92 mg/dL | Status: NORMAL | Reference: 70–99
# - HbA1c: 5.3% | Status: NORMAL | Reference: <5.7%
# - Creatinine: 1.0 mg/dL | Status: NORMAL | Reference: 0.7–1.3
# - eGFR: 82 mL/min | Status: NORMAL | Reference: >60
# - ALT: 28 U/L | Status: NORMAL | Reference: 7–40
# - AST: 25 U/L | Status: NORMAL | Reference: 10–40
# - Bilirubin Total: 0.8 mg/dL | Status: NORMAL | Reference: 0.2–1.2

# %%
diet_prompt = f"""
    You are a clinical nutritionist specializing in Pakistani dietary habits.
    Based on the blood work analysis below, write:
    1. A short health summary in 4-5 lines explaining the patient's condition in simple language
    2. A short, practical Indian diet plan having only two sections (1) Foods to avoid (2) Foods to eat more of.
    Do not include any other sections in diet plan.
    
    Blood Work Analysis:
    {extracted_values}
    """

diet_response = llm.invoke(diet_prompt)
print("== Stage 2 : Health Summary and Diet Plan ==")
print(diet_response)
# Out:
# == Stage 2 : Health Summary and Diet Plan ==
# content=[{'type': 'text', 'text': '### **Health Summary**\nYour blood counts, blood sugar, kidney, and liver functions are all completely normal and healthy. However, your lipid profile indicates dyslipidemia, meaning you have elevated levels of "bad" cholesterol (LDL) and triglycerides, alongside low "good" cholesterol (HDL). This pattern increases the risk of plaque buildup in your arteries and future cardiovascular issues. The good news is that these cholesterol markers can be effectively improved with targeted dietary modifications and lifestyle changes.\n\n---\n\n### **Diet Plan**\n\n#### **(1) Foods to Avoid**\n* **Deep-Fried & Street Snacks:** Samosas, pakoras, puris, kachoris, bhujia, and namkeen.\n* **Saturated & Trans Fats:** Dalda (vanaspati ghee), margarine, palm oil, and excessive use of butter or desi ghee.\n* **High-Fat Meats & Organ Meats:** Mutton/beef with visible fat, organ meats (*kaleji, maghaz, paya*), and processed meats.\n* **Full-Fat Dairy:** Full-cream milk, buffalo milk, *malai* (clotted cream), rich paneer, and condensed milk.\n* **Refined Carbohydrates & Sweets:** *Maida* (refined flour) items, bakery biscuits, cakes, pastries, and traditional sweets (*mithai, halwa, jalebi*).\n\n#### **(2) Foods to Eat More Of**\n* **High-Fiber Grains:** Whole wheat roti with bran (*choker*), oats, daliya (broken wheat), barley (*jowar*), and brown rice.\n* **Pulses & Legumes:** Whole lentils (*chana dal, moong, masoor*), chickpeas (*kabuli chana*), rajma, and sprouted beans.\n* **Fresh Vegetables:** Green leafy vegetables (spinach, methi), okra (*bhindi*), bottle gourd (*lauki*), karela, and plenty of raw vegetable salads with meals.\n* **Lean Proteins:** Skinless chicken breast, egg whites, and fish (such as rohu, pomfret, or salmon rich in omega-3).\n* **Heart-Healthy Fats & Seeds:** Small daily portions of raw walnuts, almonds, chia seeds, flaxseeds (*alsi*), and 1 teaspoon of psyllium husk (*isabgol*) in water before meals.', 'extras': {'signature': '...'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.7-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a034ca-4f05-7d23-aebe-9e3e494f55a9-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 480, 'output_tokens': 1199, 'total_tokens': 1679, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 699}}
